# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Handling imbalance data

# %% [markdown]
# **up_smapling = resample(df_minority ,  replace=True , n_samples=len(df_majority) , random_state=100)**
#
#
# **down_smapling = resample(df_majority , replace=False , n_samples=len(df_minority) , random_state=100)**

# %% [markdown]
# **1. Up sampling**

# %% [markdown]
# ## **NOTE : Data generated by upsampling is nothing but duplication of existing data**

# %%
np.random.seed(123)

n_sample=1000
class_0_ratio=0.90
n_class_0=int(n_sample*class_0_ratio)
n_class_1=n_sample-n_class_0

# %%
n_class_0
# Out:
# 900

# %%
n_class_1
# Out:
# 100

# %%
class_0 = pd.DataFrame({
    'feature_1' : np.random.normal(loc=0 , scale=1 , size=n_class_0),
    'feature_2' : np.random.normal(loc=0 , scale=1 , size=n_class_0),
    'target' : [0] * n_class_0
})

class_0
# Out:
#      feature_1  feature_2  target
# 0     0.667532  -0.367419       0
# 1     0.100458   0.575273       0
# 2    -0.012610   0.439351       0
# 3     0.219907  -0.728152       0
# 4     0.813623  -0.888530       0
# ..         ...        ...     ...
# 895  -0.486628   0.719991       0
# 896  -0.818430  -1.159531       0
# 897  -1.138029   0.609591       0
# 898   1.062592  -1.919582       0
# 899  -0.831040  -0.426635       0
#
# [900 rows x 3 columns]

# %%
class_1= pd.DataFrame({
    'feature_1' : np.random.normal(loc=0 , scale=1 , size=n_class_1),
    'feature_2' : np.random.normal(loc=0 , scale=1 , size=n_class_1),
    "target" : [1]*n_class_1
})

# %%
sns.displot(class_1['feature_1'] , kde=True)

# %%
df=pd.concat([class_0 , class_1])

# %%
df
# Out:
#     feature_1  feature_2  target
# 0    0.667532  -0.367419       0
# 1    0.100458   0.575273       0
# 2   -0.012610   0.439351       0
# 3    0.219907  -0.728152       0
# 4    0.813623  -0.888530       0
# ..        ...        ...     ...
# 95   0.247755  -0.619840       1
# 96   0.558893   0.524523       1
# 97  -0.948654   0.666087       1
# 98  -0.107814   0.448143       1
# 99  -1.389024   0.494382       1
#
# [1000 rows x 3 columns]

# %%
df['target'].value_counts()
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
df_minority=df[df['target'] == 1]
df_majority=df[df['target'] == 0]

# %%
df_minority
# Out:
#     feature_1  feature_2  target
# 0   -0.016102  -2.639568       1
# 1    0.747010  -0.199810       1
# 2   -0.257842  -0.322697       1
# 3    0.561622   1.526228       1
# 4    0.295353  -1.428047       1
# ..        ...        ...     ...
# 95   0.247755  -0.619840       1
# 96   0.558893   0.524523       1
# 97  -0.948654   0.666087       1
# 98  -0.107814   0.448143       1
# 99  -1.389024   0.494382       1
#
# [100 rows x 3 columns]

# %%
df_majority
# Out:
#      feature_1  feature_2  target
# 0     0.667532  -0.367419       0
# 1     0.100458   0.575273       0
# 2    -0.012610   0.439351       0
# 3     0.219907  -0.728152       0
# 4     0.813623  -0.888530       0
# ..         ...        ...     ...
# 895  -0.486628   0.719991       0
# 896  -0.818430  -1.159531       0
# 897  -1.138029   0.609591       0
# 898   1.062592  -1.919582       0
# 899  -0.831040  -0.426635       0
#
# [900 rows x 3 columns]

# %%
from sklearn.utils import resample

df_minority_upsampled=resample(df_minority , replace=True , n_samples=len(df_majority) , random_state=42)
df_minority_upsampled
# Out:
#     feature_1  feature_2  target
# 51   0.316659   0.460003       1
# 92   0.643848  -1.043793       1
# 14   0.482016   1.142197       1
# 71   1.884163   0.034512       1
# 60   0.708390  -1.655288       1
# ..        ...        ...     ...
# 52   0.064949   0.277850       1
# 65  -2.787053  -0.538162       1
# 76   0.403427  -0.956675       1
# 42  -0.950528   0.041294       1
# 74   1.252742  -0.529553       1
#
# [900 rows x 3 columns]

# %%
df_minority_upsampled.shape
# Out:
# (900, 3)

# %%
df_upsampled=pd.concat([df_majority , df_minority_upsampled ])

# %%
df_upsampled
# Out:
#     feature_1  feature_2  target
# 0    0.667532  -0.367419       0
# 1    0.100458   0.575273       0
# 2   -0.012610   0.439351       0
# 3    0.219907  -0.728152       0
# 4    0.813623  -0.888530       0
# ..        ...        ...     ...
# 52   0.064949   0.277850       1
# 65  -2.787053  -0.538162       1
# 76   0.403427  -0.956675       1
# 42  -0.950528   0.041294       1
# 74   1.252742  -0.529553       1
#
# [1800 rows x 3 columns]

# %%
df_upsampled.shape
# Out:
# (1800, 3)

# %% [markdown]
# **2 . Down Sampling**

# %%
n_sample=1000
class_0_ratio=0.90
n_class_0=int(n_sample*class_0_ratio)
n_class_1=n_sample-n_class_0

# %%
n_class_0
# Out:
# 900

# %%
n_class_1
# Out:
# 100

# %%
class_0=pd.DataFrame({
    'feature_1' : np.random.normal(loc=0 , scale=1 , size=n_class_0),
    'feature_2' : np.random.normal(loc=0 , scale=1 , size=n_class_0) , 
    'target' : [0] * n_class_0
})

# %%
class_1=pd.DataFrame({
    'feature_1' : np.random.normal(loc=0 , scale=1 , size=n_class_1),
    'feature_2' : np.random.normal(loc=0 , scale=1 , size=n_class_1) , 
    'target' : [1] * n_class_1
})

# %%
class_0.shape
# Out:
# (900, 3)

# %%
class_1.shape
# Out:
# (100, 3)

# %%
df=pd.concat([class_0 , class_1]).reset_index(drop=True)

# %%
df
# Out:
#      feature_1  feature_2  target
# 0    -0.093436  -0.650884       0
# 1     1.650653   2.079573       0
# 2    -0.845004   1.445297       0
# 3     0.395839  -0.668054       0
# 4    -1.342092  -0.581201       0
# ..         ...        ...     ...
# 995   0.580448   0.892650       1
# 996  -0.530109  -0.318481       1
# 997  -0.706474  -0.956336       1
# 998   0.171269   1.103668       1
# 999   2.052562   2.243994       1
#
# [1000 rows x 3 columns]

# %%
df['target'].value_counts()
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
from sklearn.utils import resample

df_majority=df[df['target']==0]
df_minority=df[df['target']==1]

# %%
df_majority.shape
# Out:
# (900, 3)

# %%
df_minority.shape
# Out:
# (100, 3)

# %%
df_majority_downsample=resample(df_majority , replace=False,
                               n_samples=len(df_minority) ,
                               random_state=42)

# %%
df_majority_downsample.shape
# Out:
# (100, 3)

# %%
df_minority.shape
# Out:
# (100, 3)

# %%
df_downsampled=pd.concat([df_majority_downsample  , df_minority]).reset_index(drop=True)

# %%
df_downsampled.shape
# Out:
# (200, 3)

# %%
df_downsampled
# Out:
#      feature_1  feature_2  target
# 0     0.925318   0.710721       0
# 1    -0.096751  -0.895002       0
# 2    -0.687854   0.851636       0
# 3    -1.875155   0.866108       0
# 4     1.075074  -0.636771       0
# ..         ...        ...     ...
# 195   0.580448   0.892650       1
# 196  -0.530109  -0.318481       1
# 197  -0.706474  -0.956336       1
# 198   0.171269   1.103668       1
# 199   2.052562   2.243994       1
#
# [200 rows x 3 columns]

# %% [markdown]
# **up_smapling = resample(df_minority ,  replace=True , n_samples=len(df_majority) , random_state=100)**
#
#
# **down_smapling = resample(df_majority , replace=False , n_samples=len(df_minority) , random_state=100)**

# %% [markdown]
# # Data generated by upsampling is nothing but duplication of same data

# %%
df_upsampled[df_upsampled['target']==1]
# Out:
#     feature_1  feature_2  target
# 51   0.316659   0.460003       1
# 92   0.643848  -1.043793       1
# 14   0.482016   1.142197       1
# 71   1.884163   0.034512       1
# 60   0.708390  -1.655288       1
# ..        ...        ...     ...
# 52   0.064949   0.277850       1
# 65  -2.787053  -0.538162       1
# 76   0.403427  -0.956675       1
# 42  -0.950528   0.041294       1
# 74   1.252742  -0.529553       1
#
# [900 rows x 3 columns]

# %%
df_upsampled['feature_1']
# Out:
# 0     0.667532
# 1     0.100458
# 2    -0.012610
# 3     0.219907
# 4     0.813623
#         ...
# 52    0.064949
# 65   -2.787053
# 76    0.403427
# 42   -0.950528
# 74    1.252742
# Name: feature_1, Length: 1800, dtype: float64

# %%
df_upsampled.duplicated().sum()
# Out:
# 800
