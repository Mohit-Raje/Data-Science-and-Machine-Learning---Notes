# %% [markdown]
# ## Q1. What is the relationship between polynomial functions and kernel functions in machine learning algorithms?
#
#
#
#  Imagine you have a problem where the data points are not linearly separable:
# You try to draw a straight line to separate two classes...
# But it's not working! 😵
#
# So what do you do?
#
# You transform your data into a new space where it becomes easier to separate with a straight line.
#
# 🎯 This is where Polynomial Functions come in:
# A polynomial function changes your original data like this:
#
# From
# 𝑥
# x → to
# 𝑥
# ,
# 𝑥
# 2
# ,
# 𝑥
# 3
# ,
# …
# x,x
# 2
#  ,x
# 3
#  ,…
#
# Basically: adds power terms to your features.
#
# So instead of drawing a straight line in 2D, you're now drawing a straight line in a curved feature space, which looks like a curve in the original space.
#
# ⚡ But transforming data like this manually can be slow and costly...
# That’s where the Kernel Function helps.
#
# ✅ What is a Kernel Function?
# A kernel function is a smart shortcut.
#
# Instead of manually transforming the data to higher dimensions, the kernel just calculates what the result would be if you had done that.
#
# So you get the power of a polynomial transformation… ➡️ without actually doing it!
#
# This is called the “kernel trick”.

# %% [markdown]
# ## Q2. How can we implement an SVM with a polynomial kernel in Python using Scikit-learn?

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=datasets.load_wine()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
X=pd.DataFrame(data=data['data'] , columns=data['feature_names'])
y=pd.DataFrame(data=data['target'] , columns=['Traget'])

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X  ,  y , test_size=0.3 , random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')
model=SVC(kernel='poly')
model.fit(X_train , y_train)
y_pred=model.predict(X_test)
print(accuracy_score(y_test , y_pred))
# Out:
# 0.7592592592592593

# %% [markdown]
# ## Q3. How does increasing the value of epsilon affect the number of support vectors in SVR?
#
# In SVR e is the distance between the  hyperplane and teh marginal palne . The orientation of the marginal plane and the hyperplane is decdied by the support vector . The incerasing value of epsilon incerases the distan ce between the hyperplane and the marginal plane , due which the more and more pints start entring the region between the hypeplane and the marginal plane . Due to which the number of support vectors(In soft margin the support vectors are the points on the marginal plane, between the marginla plane and the hyperplane and the points that cross the hyperlane) increses and the orinattion of the hyperplane and marginal plane changes .
#
# The epsilon which is the distnce between the hyperplane and the margins this forms aepsioln tube in SVR . The points that lie with the epsilon tube i.e the points that lie in hyplane +- epsilon are not the support vectors and are not penalized in any way . The points tha lie on the margins the upper and the lower are the support vectors but are not penlized the points the lie outside the epslion tube are also the support vectors and are penlaized .
#
# If we increse the value of epsilon the epsilon tube increases and more andmore points start entering the region of e-tube and number of support vectors decreases .

# %% [markdown]
# ## Q4. How does the choice of kernel function, C parameter, epsilon parameter, and gamma parameter affect the performance of Support Vector Regression (SVR)? Can you explain how each parameter works and provide examples of when you might want to increase or decrease its value?
#
#
# Kernel function :
#
# The kernel function is decided based on type of the data . If the data is easily seperable , then linear function of  kernel function is used this allows a staright line to separate the data easily with high accuracy . If the data is not seperable which is most common in terms of the real world scenario , in such case linear line cannot separate the data with high accuracy in such case poly or rbf or sigmoid kernel functions are used to transform the data to higher dimensionlaity and make the data easily separable .
#
# C :
#
# C is the penalty or the hyperparameter which controls the widht of the margin . If C is low the margins are wider , more points get mis classified , if C is high margin width is narrow and tight and do not allow points to get miscalssified (less points get misclassfied).
#
# epsilon :
#
# epsilon is the distnacne between the hyperplane and teh marginal plane . This form a epsilon tube around the regression line or the hyperplane . Points that fall within the epsilon tube are the once which are not support vectors and nitether penalty is applied to them . The pionts on the tube are the support vectors and the not penalty is applied . The points outside the e tube are the points which are aslo support vectors but penalty is applied . If the value of epsilon increased the e tube enlrages aloowing more and more points to fall in it , if value of epsilon is decreased the e tube shrinks and more points fall outside increasing the support vectors
#
#
#
#
# Effects of kernel, C, epsilon, and gamma in SVR
# 🔹 1. Kernel Function
# What it does:
# Transforms the input data into a higher-dimensional space where a linear regression can be applied.
#
#
# Kernel Type	When to Use
# linear	Data has a linear trend. Simple and efficient.
# poly	Data shows polynomial (curved) patterns.
# rbf	Default choice. Handles complex, nonlinear data well.
# sigmoid	Rarely used. Similar to a neural net activation.
# 🧠 Example:
#
# If your dataset is a straight line (like height vs. weight), use linear.
#
# If your data curves like a parabola, use poly.
#
# If your data looks like a cloud with no obvious pattern, use rbf.
#
# 🔹 2. C (Penalty / Regularization Term)
# What it does:
# Controls the trade-off between achieving a flat regression curve and allowing some points to be off by more than epsilon.
#
#
# Value of C	Model Behavior
# Low C	Allows wider margin → more tolerance to error → simpler model (can underfit).
# High C	Narrow margin → tries to fit every point → complex model (can overfit).
# 🧠 Example:
#
# For noisy data (e.g., predicting stock prices), use low C.
#
# For precise data (e.g., chemical measurements), use high C.
#
# 🔹 3. Epsilon (ε)
# What it does:
# Creates an ε-tube around the regression line where no penalty is given for errors (i.e., predictions within this margin are “good enough”).
#
#
# Value of ε	Model Behavior
# Low ε	Narrow tube → More points lie outside → more support vectors → higher model complexity.
# High ε	Wide tube → More tolerance → simpler model → fewer support vectors.
# 🧠 Example:
#
# For applications where small errors matter (e.g., heart rate prediction), use low ε.
#
# For tolerant systems (e.g., forecasting temperature in 5°C ranges), use high ε.
#
# 🔹 4. Gamma (only for rbf, poly, sigmoid kernels)
# What it does:
# Controls the influence of each data point. It defines how far the impact of a single training point reaches.
#
#
# Value of γ (gamma)	Model Behavior
# Low γ	Data points have a large influence → smoother curve.
# High γ	Data points have narrow influence → complex curve, may overfit.
# 🧠 Example:
#
# For generalized models (less sensitive to noise), use low gamma.
#
# For detailed fitting (e.g., when every point matters), use high gamma.
#
# ![image.png](attachment:a053c626-4c1c-4ed7-9043-cad08ee0b3e3.png)

# %% [markdown]
# ## Q5. Assignment:
# - Import the necessary libraries and load the dataseg
# - Split the dataset into training and testing setZ
# - Preprocess the data using any technique of your choice (e.g. scaling, normalizationK
# - Create an instance of the SVC classifier and train it on the training datW
# - Use the trained classifier to predict the labels of the testing datW
# - Evaluate the performance of the classifier using any metric of your choice (e.g. accuracy, recision, recall, F1-scoreK
# - Tune the hyperparameters of the SVC classifier using GridSearchCV or RandomizedSearchCV to improve its performance
# - Train the tuned classifier on the entire dataseg
# - Save the trained classifier to a file for future use.

# %%
from sklearn import datasets

# %%
data=datasets.load_breast_cancer()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X=pd.DataFrame(data=data['data'] , columns=data['feature_names'])
y=pd.DataFrame(data=data['target'] , columns=['Cancer'])

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
X.shape
# Out:
# (569, 30)

# %%
y.head()
# Out:
#    Cancer
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
y.value_counts()
# Out:
# Cancer
# 1         357
# 0         212
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.3 , random_state=42)

# %%
std=StandardScaler()
X_train=std.fit_transform(X_train)

# %%
X_test=std.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(X_train , y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix , classification_report , precision_score , recall_score , accuracy_score

# %%
print(confusion_matrix(y_test , y_pred))
print(classification_report(y_test , y_pred))
print(precision_score(y_test , y_pred))
print(recall_score(y_test , y_pred))
print(accuracy_score(y_test , y_pred))
# Out:
# [[ 61   2]
#  [  2 106]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        63
#            1       0.98      0.98      0.98       108
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171
#
# 0.9814814814814815
# 0.9814814814814815
# 0.9766081871345029

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10, 100],               # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],  # Kernel types
    'gamma': ['scale', 'auto', 0.01, 0.001],         # Kernel coefficient
    'degree': [2, 3, 4, 5]                # Used only for 'poly' kernel
}

gscv=GridSearchCV(SVC() , param_grid , cv=5 , refit=True , verbose=1)
gscv
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4, 5],
#                          'gamma': ['scale', 'auto', 0.01, 0.001],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=1)

# %%
gscv.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4, 5],
#                          'gamma': ['scale', 'auto', 0.01, 0.001],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=1)

# %%
gscv.best_params_
# Out:
# {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %%
gscv.best_score_
# Out:
# 0.9748417721518987

# %%
svc1=SVC(C=1 , degree=2 , gamma='scale' , kernel='linear'  , probability=True)

# %%
svc1.fit(X_train , y_train)
# Out:
# SVC(C=1, degree=2, kernel='linear', probability=True)

# %%
y_pred1=svc1.predict(X_test)

# %%
print(confusion_matrix(y_test , y_pred1))
print(classification_report(y_test , y_pred1))
print(precision_score(y_test , y_pred1))
print(recall_score(y_test , y_pred1))
print(accuracy_score(y_test , y_pred1))
# Out:
# [[ 61   2]
#  [  2 106]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        63
#            1       0.98      0.98      0.98       108
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171
#
# 0.9814814814814815
# 0.9814814814814815
# 0.9766081871345029

# %%
from sklearn.metrics import roc_curve , roc_auc_score , f1_score

# %%
y_proba=svc1.predict_proba(X_test)[: , 1]

# %%
fpr , tpr , threshold = roc_curve(y_test , y_proba)

# %%
plt.figure(figsize=(8 , 5))
plt.plot(fpr , tpr)
plt.plot([0,1] , linestyle='--' , color='orange')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.tight_layout()
plt.show()
