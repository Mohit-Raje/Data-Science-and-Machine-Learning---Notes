# %% [markdown]
# ## Q1. What is Bayes' theorem?
#
# Bayes theorem :
#
# P(A|B)= P(A) * P(B|A) / P(B)
#
# Bayes’ Theorem says:
# It helps us update the probability of something happening based on new information.
#
# 💬 In plain words:
# “If I know something new, how should I change what I believe?”
#
# 🧪 Example:
# You think it might rain today (say, 30% chance)
#
# But now you see dark clouds 🌧️
#
# Bayes' theorem helps you update that 30% to something higher — maybe 70% — because of the new evidence (clouds)

# %% [markdown]
# ## Q2. What is the formula for Bayes' theorem?
#
#
# P(A|B) = P(B|A) * P(A)/P(B)

# %% [markdown]
# ## Q3. How is Bayes' theorem used in practice?
#
# Bayes’ Theorem is used to make decisions or predictions when new evidence is available. It helps us update probabilities based on that evidence.
#
# 🛠️ Practical Applications:
# 1. 🧪 Medical Diagnosis
# Doctors use it to find the chance a patient has a disease after getting test results.
#
# Example: If a test is positive, what’s the real chance you’re sick?
#
# 2. 🕵️ Spam Detection
# Email services use it to calculate the probability an email is spam based on words it contains.
#
# If it has words like "free", "win", etc., it’s more likely to be spam.
#
# 3. 📈 Machine Learning (Naive Bayes Classifier)
# A very fast and popular algorithm for text classification (e.g., sentiment analysis, spam filtering).
#
# It uses Bayes’ theorem to predict the most likely class of data.
#
# 4. 🎯 Recommendation Systems
# Used to update predictions about what users like based on their actions (clicks, likes, etc.)
#
# 5. 👮 Crime & Forensics
# Helps estimate the chance a suspect is guilty given DNA or other evidence.
#
# 💡 Simple Idea Recap:
# Start with a belief → get new data → update the belief.

# %% [markdown]
# ## Q4. What is the relationship between Bayes' theorem and conditional probability?
#
# 🔗 Relationship:
# Conditional probability is the probability of an event A happening given that another event B has already occurred.
#
# 𝑃
# (𝐴∣𝐵)
#
# Bayes' Theorem uses conditional probability to update the probability of an event based on new evidence.
#
# 🧠 In simple words:
# Conditional probability tells us how likely something is if something else has happened.
# Bayes’ theorem uses that idea to help us recalculate the chance of an event as new info comes in.
#
# 🪄 How it works:
# You start with a belief (prior probability)
#
# You get new data (evidence)
#
# Bayes’ theorem helps you update the belief using conditional probability
#
# ![image.png](attachment:8e21d3d0-ee87-4501-8503-0dde78734542.png)

# %% [markdown]
# ## Q5. How do you choose which type of Naive Bayes classifier to use for any given problem?
#
#
# 1. Bernoulli Naive Bayes
# This variant is used when the data follows a Bernoulli distribution, i.e., binary features.
#
# All the independent features must have values like:
#
# 0 or 1
#
# Yes or No
#
# Pass or Fail
#
# Male or Female, etc.
#
# 👉 Use it when features are boolean or binary in nature.
#
# 2. Multinomial Naive Bayes
# This variant is used when the independent features are text data, especially in count-based representations (like word counts).
#
# Example: In spam email classification, the input is an email (text), and it's represented by word frequencies.
#
# 👉 Best suited for document classification, text classification, and natural language processing tasks.
#
# 3. Gaussian Naive Bayes
# This variant is used when the independent features are continuous values and follow a Gaussian (normal) distribution.
#
# Example: Predicting a label based on features like height, weight, or temperature.
#
# 👉 Use it when your features are real-valued and normally distributed.
