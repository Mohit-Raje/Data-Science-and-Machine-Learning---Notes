# %% [markdown]
# ## Q1. What is the KNN algorithm?
#
# Q1. What is the KNN algorithm?
# KNN (K-Nearest Neighbors) is a supervised machine learning algorithm used for both classification and regression tasks.
#
# 🧠 How it Works (Classification):
# When given a new data point to classify, KNN:
#
# Looks at the ‘k’ closest data points from the training set.
#
# Counts the classes of those neighbors.
#
# Assigns the most common class among them to the new point.
#
# 📦 Example:
# Suppose k=3 and a new point is surrounded by:
#
# 2 "Cats"
#
# 1 "Dog"
#
# Then, the KNN algorithm will classify the point as a "Cat".
#
# 📏 Key Ideas:
# It uses distance (commonly Euclidean) to find neighbors.
#
# Lazy learner: It doesn't learn a model; it just stores the data.
#
# Works best when data is not too high-dimensional and is scaled properly.
#
# 🧮 Distance Used:
# Euclidean (default), Manhattan, Minkowski, etc.
#
# You can customize the distance function in the model.
#
# Pros:
# Simple to understand and implement
#
# No training time
#
# Naturally handles multi-class problems
#
# Cons:
# Slow prediction on large datasets
#
# Sensitive to irrelevant features and scaling
#
# Doesn't work well with high-dimensional data (curse of dimensionality)

# %% [markdown]
# ## Q2. How do you choose the value of K in KNN?
#
# The value of K in KNN is chosen using hyperparameter tuning (like cross-validation) or based on domain knowledge

# %% [markdown]
# ## Q3. What is the difference between KNN classifier and KNN regressor?
#
# The main difference KNN classifier and regressor is the way in which they combine results obtained by the n neighbours . In case of classification majority voting is used i.e the class to which majority of the neighbour belongs that calss is assigned to the test data point . IN case of regression n nearest neighbours of the test data are considered and their avg is the result .
#
# KNN Classifier uses majority voting among neighbors to predict the class, while KNN Regressor uses the average (or weighted average) of neighbors' values to predict a continuous output
#
# Both methods use the same distance-based approach to find neighbors, but differ in how the final prediction is made.

# %% [markdown]
# ## Q4. How do you measure the performance of KNN?
#
# Classification:
#
# To measure performance: use metrics like accuracy_score, confusion_matrix, and ROC curve.
#
# For error analysis: use precision (to evaluate false positives) and recall (to evaluate false negatives).
#
# classification_report provides a summary of precision, recall, f1-score, and support.
#
# Regression:
#
# For accuracy: use R² score (coefficient of determination).
#
# For error: use MAE (Mean Absolute Error), MSE (Mean Squared Error), and RMSE (Root Mean Squared Error).

# %% [markdown]
# ## Q5. What is the curse of dimensionality in KNN?
#
# The curse of dimensionality refers to the problems that arise when working with data in high-dimensional spaces. In KNN, as the number of features increases, the distance between points becomes less meaningful — all points start to appear equally far. This degrades the performance of KNN, as it relies on meaningful distance to find nearest neighbors. It often leads to high variance and poor generalization.

# %% [markdown]
# ## Q6. How do you handle missing values in KNN?
#
# In KNN, missing values are typically handled through imputation. Common methods include replacing missing values with the mean, median, or mode of the feature. More advanced methods use KNN imputation, where the missing value is filled based on the values from the nearest neighbors.

# %% [markdown]
# ## Q7. Compare and contrast the performance of the KNN classifier and regressor. Which one is better for which type of problem?
#
# NN Classifier is used for categorical output, where the goal is to assign a class label based on the majority vote from nearest neighbors. It works well for problems like image classification, spam detection, or disease diagnosis.
#
# KNN Regressor is used for continuous output, where the prediction is the average (or weighted average) of the neighbors’ values. It is suitable for problems like predicting house prices, temperature, or stock values
#
# ![image.png](attachment:6181ff11-cdad-4466-bb58-9ac34f2e27b4.png)

# %% [markdown]
# ## Q8. What are the strengths and weaknesses of the KNN algorithm for classification and regression tasks, and how can these be addressed?
#
# **Strengths (Common to both classification & regression):**
#
# Simple & intuitive – Easy to understand and implement.
#
# No training time – It’s a lazy learner; just stores the training data.
#
# Versatile – Can be used for both classification and regression.
#
# Non-parametric – No assumptions about data distribution.
#
# **Weaknesses**
#
#
#
# Slow at prediction
#
# Curse of dimensionality
#
# Sensitive to noise/outliers

# %% [markdown]
# ## Q9. What is the difference between Euclidean distance and Manhattan distance in KNN?
#
# Euclidean distance is the straight-line distance between two points (like using a ruler).
# Manhattan distance is the sum of the absolute differences along each dimension (like moving in a grid or city blocks).
#
# ![image.png](attachment:7f67c5c9-4253-4724-9155-c0a4d9035ea5.png)
#
# Euclidean is better when all features are continuous and there's no strong axis alignment.
#
# Manhattan is often better when data is sparse, or has many dimensions, or when features are aligned with axes.
#
#
#
# Euclidean distance is like drawing a straight line between two points — it's best when the data is continuous and features aren't restricted to any particular direction.
#
# Manhattan distance is like walking in a city — you move along the blocks, not diagonally. It's better when the data is sparse, has lots of zeros, or is high-dimensional, because it handles those cases more reliably.

# %% [markdown]
# ## Q10. What is the role of feature scaling in KNN?
#
#
# Feature scaling is crucial in KNN because the algorithm relies on distance calculations. If features are on different scales (e.g., age in years vs. income in lakhs), the feature with the larger scale will dominate the distance — and this can lead to biased or incorrect predictions.
